# %%
M = int(input())

temp = 1

for i in range(M): 
  X,Y = map(int, input().split())

  if(X == temp): # X와 같으면 교환
    temp = Y
  elif(Y == temp): # Y와 같으면 교환
    temp = X

print(temp)
# Out:
# 5
# 2 3
# 1 3
# 2 3
# 2 1
# 3 1
# 3
